# %%
import pandas as pd
import sklearn
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,roc_auc_score,roc_curve

# %%
print(sklearn.__version__)
# Out:
# 1.7.2

# %%
df = pd.read_csv('./data/cardio_processed_data.csv')

# %%
df
# Out:
#        age  gender  height  weight        bmi  ap_hi  ap_lo  cholesterol  \
# 0       50       0     168    62.0  21.967120    110     80            1
# 1       55       0     156    85.0  34.927679    140     90            3
# 2       51       0     165    64.0  23.507805    130     70            3
# 3       48       0     169    82.0  28.710479    150    100            1
# 4       47       0     156    56.0  23.011177    100     60            1
# ...    ...     ...     ...     ...        ...    ...    ...          ...
# 68545   52       0     168    76.0  26.927438    120     80            1
# 68546   61       0     158   126.0  50.472681    140     90            2
# 68547   52       0     183   105.0  31.353579    180     90            3
# 68548   61       0     163    72.0  27.099251    135     80            1
# 68549   56       0     170    72.0  24.913495    120     80            2
#
#        gluc  smoke  alco  active  pulse_pressure  cardio
# 0         1      0     0       1              30       0
# 1         1      0     0       1              50       1
# 2         1      0     0       0              60       1
# 3         1      0     0       1              50       1
# 4         1      0     0       0              40       0
# ...     ...    ...   ...     ...             ...     ...
# 68545     1      1     0       1              40       0
# 68546     2      0     0       1              50       1
# 68547     1      0     1       0              90       1
# 68548     2      0     0       0              55       1
# 68549     1      0     0       1              40       0
#
# [68550 rows x 14 columns]

# %%
plt.scatter(df['height'] , df['cardio'])

# %%
plt.scatter(df['weight'] , df['cardio'])

# %%
plt.scatter(df['bmi'] , df['cardio'])

# %%
plt.scatter(df['ap_hi'] , df['cardio'])

# %%
df.head()
# Out:
#    age  gender  height  weight        bmi  ap_hi  ap_lo  cholesterol  gluc  \
# 0   50       0     168    62.0  21.967120    110     80            1     1
# 1   55       0     156    85.0  34.927679    140     90            3     1
# 2   51       0     165    64.0  23.507805    130     70            3     1
# 3   48       0     169    82.0  28.710479    150    100            1     1
# 4   47       0     156    56.0  23.011177    100     60            1     1
#
#    smoke  alco  active  pulse_pressure  cardio
# 0      0     0       1              30       0
# 1      0     0       1              50       1
# 2      0     0       0              60       1
# 3      0     0       1              50       1
# 4      0     0       0              40       0

# %%
df['cardio'].value_counts(normalize=True)
# Out:
# cardio
# 0    0.505062
# 1    0.494938
# Name: proportion, dtype: float64

# %%
x = df.drop('cardio',axis=1)

# %%
y = df['cardio']

# %%
x.head()
# Out:
#    age  gender  height  weight        bmi  ap_hi  ap_lo  cholesterol  gluc  \
# 0   50       0     168    62.0  21.967120    110     80            1     1
# 1   55       0     156    85.0  34.927679    140     90            3     1
# 2   51       0     165    64.0  23.507805    130     70            3     1
# 3   48       0     169    82.0  28.710479    150    100            1     1
# 4   47       0     156    56.0  23.011177    100     60            1     1
#
#    smoke  alco  active  pulse_pressure
# 0      0     0       1              30
# 1      0     0       1              50
# 2      0     0       0              60
# 3      0     0       1              50
# 4      0     0       0              40

# %%
y.head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: cardio, dtype: int64

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,stratify=y)

# %%
# len(x_train)
x_train.shape
# Out:
# (54840, 13)

# %%
# len(x_test)
x_test.shape
# Out:
# (13710, 13)

# %%
x_train
# Out:
#        age  gender  height  weight        bmi  ap_hi  ap_lo  cholesterol  \
# 16395   43       0     147    70.0  32.393910    110     60            1
# 65934   39       0     168    76.0  26.927438    110     70            1
# 16364   46       0     156    84.0  34.516765    110     70            1
# 39672   46       0     157    66.0  26.775934    110     80            1
# 4578    51       0     175    78.0  25.469388    120    100            3
# ...    ...     ...     ...     ...        ...    ...    ...          ...
# 51626   51       0     167    98.0  35.139302    130     90            2
# 23447   51       0     162    88.0  33.531474    120     80            1
# 4163    59       0     156    66.0  27.120316    140     90            1
# 5363    54       0     173    70.0  23.388687    120     80            1
# 15808   45       0     166    77.0  27.943098    110     70            1
#
#        gluc  smoke  alco  active  pulse_pressure
# 16395     1      1     1       0              50
# 65934     3      0     0       0              40
# 16364     1      0     0       0              40
# 39672     1      0     1       1              30
# 4578      3      0     0       1              20
# ...     ...    ...   ...     ...             ...
# 51626     2      0     0       1              40
# 23447     1      0     0       1              40
# 4163      1      0     0       1              50
# 5363      1      0     0       1              40
# 15808     1      1     0       1              40
#
# [54840 rows x 13 columns]

# %%
y_train
# Out:
# 16395    1
# 65934    0
# 16364    0
# 39672    0
# 4578     1
#         ..
# 51626    1
# 23447    1
# 4163     1
# 5363     0
# 15808    0
# Name: cardio, Length: 54840, dtype: int64

# %%
clf = LinearRegression()

# %%
clf.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
clf.predict(x_test)
# Out:
# array([0.39947124, 0.73931462, 0.6207491 , ..., 0.95588446, 0.30874708,
#        0.73021585], shape=(13710,))

# %%
y_test
# Out:
# 33887    1
# 6213     1
# 22803    1
# 22921    0
# 62960    1
#         ..
# 50207    1
# 40635    1
# 28720    1
# 57785    0
# 33577    1
# Name: cardio, Length: 13710, dtype: int64

# %%
clf.score(x_test,y_test) * 100
# Out:
# 17.734437017890837

# %% [markdown]
# # Linear regression will not work here
